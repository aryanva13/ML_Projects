# %% [markdown]
# ## **IMPORTING IMPORTANT LIBRARIES**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## **READING CSV FILE**

# %%
df=pd.read_csv("e-shop_clothing.csv")
df.head()
# Out:
#    year  month  day  order  country  session ID  page 1 (main category)  \
# 0  2008      4    1      1       29           1                       1
# 1  2008      4    1      2       29           1                       1
# 2  2008      4    1      3       29           1                       2
# 3  2008      4    1      4       29           1                       2
# 4  2008      4    1      5       29           1                       2
#
#   page 2 (clothing model)  colour  location  model photography  price  \
# 0                     A13       1         5                  1     28
# 1                     A16       1         6                  1     33
# 2                      B4      10         2                  1     52
# 3                     B17       6         6                  2     38
# 4                      B8       4         3                  2     52
#
#    price 2  page
# 0        2     1
# 1        2     1
# 2        1     1
# 3        2     1
# 4        1     1

# %% [markdown]
# ## **CHECKING FOR DATA TYPES AND NULL VALUES**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165474 entries, 0 to 165473
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   year                     165474 non-null  int64
#  1   month                    165474 non-null  int64
#  2   day                      165474 non-null  int64
#  3   order                    165474 non-null  int64
#  4   country                  165474 non-null  int64
#  5   session ID               165474 non-null  int64
#  6   page 1 (main category)   165474 non-null  int64
#  7   page 2 (clothing model)  165474 non-null  object
#  8   colour                   165474 non-null  int64
#  9   location                 165474 non-null  int64
#  10  model photography        165474 non-null  int64
#  11  price                    165474 non-null  int64
#  12  price 2                  165474 non-null  int64
#  13  page                     165474 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                            count       mean        std   min   25%   50%  \
# month                   165474.0   5.585887   1.328160   4.0   4.0   5.0
# day                     165474.0  14.524554   8.830374   1.0   7.0  14.0
# order                   165474.0   9.817476  13.478411   1.0   2.0   6.0
# country                 165474.0  26.952621   7.150691   1.0  29.0  29.0
# page 1 (main category)  165474.0   2.400842   1.144420   1.0   1.0   2.0
# colour                  165474.0   6.227655   4.235606   1.0   3.0   4.0
# location                165474.0   3.258198   1.713206   1.0   2.0   3.0
# model photography       165474.0   1.260071   0.438674   1.0   1.0   1.0
# price                   165474.0  43.802507  12.548131  18.0  33.0  43.0
# page                    165474.0   1.710166   0.982412   1.0   1.0   1.0
#
#                          75%    max
# month                    7.0    8.0
# day                     22.0   31.0
# order                   12.0  195.0
# ...

# %%
df.isna().sum()
# Out:
# year                       0
# month                      0
# day                        0
# order                      0
# country                    0
# session ID                 0
# page 1 (main category)     0
# page 2 (clothing model)    0
# colour                     0
# location                   0
# model photography          0
# price                      0
# price 2                    0
# page                       0
# dtype: int64

# %%
dataset=df
dataset1=df
dataset2=df

# %% [markdown]
# ##**FINDING TARGET FUNCTION AND REMOVING IRRELEVANT FEATURES**

# %%
df['location'].value_counts()
# Out:
# 1    34532
# 2    33383
# 5    27783
# 4    27377
# 3    21656
# 6    20743
# Name: location, dtype: int64

# %%
df['price 2']=[0 if i==1 else 1 for i in df['price 2']]

# %%
df['page 1 (main category)'].value_counts()
# Out:
# 1    49742
# 4    38747
# 3    38577
# 2    38408
# Name: page 1 (main category), dtype: int64

# %%
df['session ID'].value_counts()
# Out:
# 22433    195
# 13846    192
# 22902    185
# 8201     161
# 19623    142
#         ...
# 9304       1
# 12449      1
# 4663       1
# 9308       1
# 19217      1
# Name: session ID, Length: 24026, dtype: int64

# %%
df['colour'].value_counts()
# Out:
# 2     29764
# 3     29259
# 6     17476
# 4     16517
# 14    15939
# 9     13531
# 12     8830
# 1      7785
# 7      6876
# 13     6295
# 11     5292
# 10     3579
# 8      2664
# 5      1667
# Name: colour, dtype: int64

# %%
df['model photography'].value_counts()
# Out:
# 1    122439
# 2     43035
# Name: model photography, dtype: int64

# %%
df['page'].value_counts()
# Out:
# 1    93452
# 2    41037
# 3    19301
# 4     8861
# 5     2823
# Name: page, dtype: int64

# %%
df['page 2 (clothing model)'].value_counts()
# Out:
# B4     3579
# A2     3013
# A11    2789
# P1     2681
# B10    2566
#        ...
# P66      46
# P22       2
# P79       2
# P54       1
# P28       1
# Name: page 2 (clothing model), Length: 217, dtype: int64

# %%
df['price 2'].value_counts()
# Out:
# 0    84695
# 1    80779
# Name: price 2, dtype: int64

# %%
df['year'].value_counts()
# Out:
# 2008    165474
# Name: year, dtype: int64

# %%
df['country'].value_counts()
# Out:
# 29    133963
# 9      18003
# 24      4091
# 46      2522
# 44      1385
# 16       834
# 21       811
# 34       716
# 41       684
# 3        256
# 27       227
# 12       210
# 42       170
# 37       163
# 10       152
# 31       144
# 22       144
# 28       139
# 38       137
# 15       125
# 11       115
# 25        71
# 2         58
# 32        49
# 23        46
# 14        43
# 39        34
# 43        31
# 19        29
# 17        23
# 36        19
# 18        18
# 20        10
# 7          9
# 47         7
# 45         6
# 6          5
# 30         5
# 5          4
# 33         3
# 1          3
# 35         3
# 13         2
# 26         2
# 40         1
# 4          1
# 8          1
# Name: country, dtype: int64

# %%
df['location'].nunique()
# Out:
# 6

# %%
df['year'].nunique()
# Out:
# 1

# %%
df=df.drop(['page 2 (clothing model)','session ID','year'],axis=1) 
#SINCE [session ID, page 2 (clothing model) and year] contain 24026,217 and 1 value respectively 
#they're of no use.Therefore,they are dropped.

# %%
def utils_recognize_type(df, col, max_cat=20):
    if (df[col].dtype == "O") | (df[col].nunique() < max_cat):
        return "cat"
    else:
        return "num"
dic_cols = {col:utils_recognize_type(df, col, max_cat=20) for col in df.columns}
print(dic_cols)
# Out:
# {'month': 'cat', 'day': 'num', 'order': 'num', 'country': 'num', 'page 1 (main category)': 'cat', 'colour': 'cat', 'location': 'cat', 'model photography': 'cat', 'price': 'num', 'price 2': 'cat', 'page': 'cat'}

# %%
#Since price has 2 categories with evenly 
#distributed data,we chose it as target function.

# %%
target=df['price 2']
df=df.drop('price 2',axis=1)

# %% [markdown]
# ##**SPLITTING THE DATASET INTO TRAINING AND TESTING DATA**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df, target, test_size = 0.25, random_state = 0)

# %%
print(X_train)
# Out:
#         month  day  order  country  page 1 (main category)  colour  location  \
# 62301       5   13      2       29                       3       6         4
# 115903      6   30      1       24                       4       2         1
# 55949       5    8      1       29                       2      14         2
# 136146      7   18     23       29                       3      13         2
# 46104       4   29     10       29                       1       1         6
# ...       ...  ...    ...      ...                     ...     ...       ...
# 97639       6   13      1       29                       3      13         3
# 95939       6   11      9        9                       1       4         2
# 152315      8    1     18       29                       4       2         3
# 117952      7    2      6       29                       2       7         2
# 43567       4   27     12       29                       4       6         3
#
#         model photography  price  page
# ...

# %% [markdown]
# ##**SCALING THE DATA USING STANDARD SCALER**

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
col=['price']
X_train = sc.fit_transform(X_train)
X_test= sc.transform(X_test)

# %% [markdown]
# ##**IMPLEMENTING PRINCIPAL COMPONENT ANALYSIS**

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components =7) #reducing number of fetaures to 7
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
print(X_train)
# Out:
# [[ 6.70921961e-01 -6.28178594e-01 -8.44228511e-02 ... -9.54338043e-02
#   -5.45169859e-01 -9.39163993e-01]
#  [-5.37333627e-01  8.83914583e-02  3.08233275e-02 ...  1.36375351e+00
#   -1.20246266e-01 -4.39252814e-02]
#  [ 2.61834642e-01 -1.45278177e-02  1.82778274e-03 ... -1.54654418e+00
#   -6.22957953e-01 -1.21699175e+00]
#  ...
#  [ 5.64520557e-01  4.99770349e-01 -2.21636032e+00 ...  4.10891489e-01
#   -3.36369221e-01  1.05950394e+00]
#  [-7.22717133e-02  9.95449294e-01 -1.35557332e+00 ... -7.94356010e-01
#   -4.05623747e-01  3.17190500e-02]
#  [ 1.89758656e+00 -1.17497260e+00  8.36885781e-01 ...  1.15289659e+00
#   -6.83566327e-01 -6.88326452e-02]]

# %% [markdown]
# ##**IMPLEMENTING KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_absolute_error, mean_squared_error,accuracy_score

# %%
from sklearn.model_selection import train_test_split, cross_val_score
k_values = list(range(1, 15))
mean_accuracy_scores = []
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    accuracy_scores = cross_val_score(knn, X_train, y_train, cv=5)  
    mean_accuracy_scores.append(np.mean(accuracy_scores))
optimal_k = k_values[np.argmax(mean_accuracy_scores)]
print("Mean Accuracy Scores:")
for k, accuracy in zip(k_values, mean_accuracy_scores):
    print(f"k = {k}: Accuracy = {accuracy:.4f}")
print("Optimal k:", optimal_k)
# Out:
# Mean Accuracy Scores:
# k = 1: Accuracy = 0.9827
# k = 2: Accuracy = 0.9766
# k = 3: Accuracy = 0.9782
# k = 4: Accuracy = 0.9742
# k = 5: Accuracy = 0.9747
# k = 6: Accuracy = 0.9717
# k = 7: Accuracy = 0.9715
# k = 8: Accuracy = 0.9686
# k = 9: Accuracy = 0.9682
# k = 10: Accuracy = 0.9661
# k = 11: Accuracy = 0.9657
# k = 12: Accuracy = 0.9638
# k = 13: Accuracy = 0.9631
# k = 14: Accuracy = 0.9612
# Optimal k: 1

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize=(12, 6))
plt.plot(range(1, 15), mean_accuracy_scores, color='red', linestyle='dashed', marker='o',markerfacecolor='blue', markersize=10)
plt.title('K Value Accuracy Scores')
plt.xlabel('K Value')
plt.ylabel('Accuracy Score')
# Out:
# Text(0, 0.5, 'Accuracy Score')

# %%
#Since KNN is not fitting well on our Dataset we choose another classifier and choosing
#k=1 on a large dataset can lead to overfitting and the model becomes too specific to the
#training data and may not generalize well to unseen data. Overfitting can result in high 
#variance and poor performance on test data or new observations.

# %% [markdown]
# ##**IMPLEMENTING DECISION TREE**

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(criterion='gini',splitter='best',max_depth=100000)
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
import seaborn as sns
print("Accuracy:",accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9420097174212575

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94     21211
#            1       0.94      0.94      0.94     20158
#
#     accuracy                           0.94     41369
#    macro avg       0.94      0.94      0.94     41369
# weighted avg       0.94      0.94      0.94     41369

# %%
cm=confusion_matrix(y_test, y_pred)
print(cm)
classes_names = ['price 1','price 2',]
cm = pd.DataFrame(confusion_matrix(y_test, y_pred),columns=classes_names, index = classes_names)
sns.heatmap(cm, annot=True, fmt='d');
# Out:
# [[19964  1247]
#  [ 1152 19006]]

# %%
print(y_test)
# Out:
# 115442    1
# 122260    0
# 83729     1
# 89232     1
# 54789     1
#          ..
# 36314     1
# 134932    0
# 138328    1
# 102094    0
# 12379     1
# Name: price 2, Length: 41369, dtype: int64

# %%
from yellowbrick.classifier import ROCAUC
def plot_ROC_curve(model, xtrain, ytrain, xtest, ytest):
    visualizer = ROCAUC(model, encoder={0: 'price 1', 
                                        1: 'price 2'})                                   
    visualizer.fit(xtrain, ytrain)
    visualizer.score(xtest, ytest)
    visualizer.show()
    return visualizer
plot_ROC_curve(clf, X_train,y_train,X_test, y_test)
# Out:
# ROCAUC(ax=<Axes: title={'center': 'ROC Curves for DecisionTreeClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={0: 'price 1', 1: 'price 2'},
#        estimator=DecisionTreeClassifier(max_depth=100000))

# %% [markdown]
# ##**IMPLEMENTING RANDOM FOREST**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf_random = RandomForestClassifier(n_estimators = 30, criterion = 'entropy', random_state =0)
clf_random = clf_random.fit(X_train,y_train)
y_pred_random = clf_random.predict(X_test)

# %%
print("Accuracy:",accuracy_score(y_test, y_pred_random))
# Out:
# Accuracy: 0.9732650051971283

# %%
print("Accuracy:",accuracy_score(y_test, y_pred_random))
# Out:
# Accuracy: 0.9732650051971283

# %%
cm=confusion_matrix(y_test, y_pred_random)
print(cm)
classes_names = ['price 1','price 2']
cm = pd.DataFrame(confusion_matrix(y_test, y_pred_random),columns=classes_names, index = classes_names)
sns.heatmap(cm, annot=True, fmt='d');
# Out:
# [[20647   564]
#  [  542 19616]]

# %%
plot_ROC_curve(clf_random, X_train, y_train, X_test, y_test)
# Out:
# ROCAUC(ax=<Axes: title={'center': 'ROC Curves for RandomForestClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={0: 'price 1', 1: 'price 2'},
#        estimator=RandomForestClassifier(criterion='entropy', n_estimators=30,
#                                         random_state=0))

# %% [markdown]
# ##**IMPLEMENTING NAIVE BAYES**

# %%
from sklearn.naive_bayes import GaussianNB
clf_naive = GaussianNB()
clf_naive.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred_naive = clf_naive.predict(X_test)
print("Accuracy:",accuracy_score(y_test, y_pred_naive))
# Out:
# Accuracy: 0.7263893253402306

# %%
cm=confusion_matrix(y_test, y_pred_naive)
print(cm)
classes_names = ['price 1','price 2']
cm = pd.DataFrame(confusion_matrix(y_test, y_pred_naive),columns=classes_names, index = classes_names)
sns.heatmap(cm, annot=True, fmt='d');
# Out:
# [[15588  5623]
#  [ 5696 14462]]

# %%
plot_ROC_curve(clf_naive, X_train, y_train, X_test, y_test)
# Out:
# ROCAUC(ax=<Axes: title={'center': 'ROC Curves for GaussianNB'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={0: 'price 1', 1: 'price 2'}, estimator=GaussianNB())

# %% [markdown]
# ##**IMPLEMENTING PERCEPTRON AND LOGISTIC REGRESSION**

# %%
from sklearn.linear_model import Perceptron,LogisticRegression
clf_per=Perceptron(alpha=0.001,l1_ratio=0.15,max_iter=10000) 
clf_lr=LogisticRegression(penalty='l2',tol=0.0001,C=1.0,max_iter=10000)
clf_per.fit(X_train, y_train)
clf_lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
y_pred_per = clf_per.predict(X_test)
y_pred_lr = clf_lr.predict(X_test)

# %%
print("Accuracy:",accuracy_score(y_test, y_pred_per))
print("Accuracy:",accuracy_score(y_test, y_pred_lr))
# Out:
# Accuracy: 0.719814353743141
# Accuracy: 0.7242379559573594

# %%
cm=confusion_matrix(y_test, y_pred_per)
print(cm)
classes_names = ['price 1','price 2']
cm = pd.DataFrame(confusion_matrix(y_test, y_pred_per),columns=classes_names, index = classes_names)
sns.heatmap(cm, annot=True, fmt='d');
# Out:
# [[12976  8235]
#  [ 3356 16802]]

# %%
cm=confusion_matrix(y_test, y_pred_lr)
print(cm)
classes_names = ['price 1','price 2']
cm = pd.DataFrame(confusion_matrix(y_test, y_pred_lr),columns=classes_names, index = classes_names)
sns.heatmap(cm, annot=True, fmt='d');
# Out:
# [[15714  5497]
#  [ 5911 14247]]

# %%
plot_ROC_curve(clf_lr, X_train, y_train, X_test, y_test)
# Out:
# ROCAUC(ax=<Axes: title={'center': 'ROC Curves for LogisticRegression'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={0: 'price 1', 1: 'price 2'},
#        estimator=LogisticRegression(max_iter=10000))
